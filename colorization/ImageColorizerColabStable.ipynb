# %% [markdown]
# <a href="https://colab.research.google.com/github/jantic/DeOldify/blob/master/ImageColorizerColabStable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **<font color='blue'> Stable Colorizer </font>**

# %% [markdown]
# #◢ DeOldify - Colorize your own photos!
#
# ####**Credits:**
#
# Special thanks to:
#
# Matt Robinson and María Benavente for pioneering the DeOldify image colab notebook.
#
# Dana Kelley for doing things, breaking stuff & having an opinion on everything.

# %% [markdown]
# ---
#
#
# #◢ Verify Correct Runtime Settings
#
# **<font color='#FF000'> IMPORTANT </font>**
#
# In the "Runtime" menu for the notebook window, select "Change runtime type." Ensure that the following are selected:
# * Runtime Type = Python 3
# * Hardware Accelerator = GPU

# %% [markdown]
# #◢ Git clone and install DeOldify

# %%
# !git clone https://github.com/jantic/DeOldify.git DeOldify
# Out:
# fatal: destination path 'DeOldify' already exists and is not an empty directory.

# %%
cd DeOldify
# Out:
# /media/tsmc/E/hgsh/DeOldify/DeOldify

# %% [markdown]
# #◢ Setup

# %%
#NOTE:  This must be the first call in order to work properly!
from deoldify import device
from deoldify.device_id import DeviceId
#choices:  CPU, GPU0...GPU7
device.set(device=DeviceId.GPU0)

import torch

if not torch.cuda.is_available():
    print('GPU not available.')

# %%
# !pip install -r requirements-colab.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: fastai==1.0.60 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from -r requirements-colab.txt (line 1)) (1.0.60)
# Requirement already satisfied: tensorboardX>=1.6 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from -r requirements-colab.txt (line 2)) (2.6)
# Requirement already satisfied: ffmpeg-python in /home/tsmc/anaconda3/lib/python3.8/site-packages (from -r requirements-colab.txt (line 3)) (0.2.0)
# Requirement already satisfied: yt-dlp in /home/tsmc/anaconda3/lib/python3.8/site-packages (from -r requirements-colab.txt (line 4)) (2023.1.6)
# Requirement already satisfied: opencv-python>=4.2.0.32 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from -r requirements-colab.txt (line 5)) (4.5.1.48)
# Requirement already satisfied: Pillow in /home/tsmc/anaconda3/lib/python3.8/site-packages (from -r requirements-colab.txt (line 6)) (9.4.0)
# Requirement already satisfied: tornado in /home/tsmc/anaconda3/lib/python3.8/site-packages (from -r requirements-colab.txt (line 7)) (6.1)
# Requirement already satisfied: imgaug==0.2.6 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from -r requirements-colab.txt (line 8)) (0.2.6)
# Requirement already satisfied: torchvision in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.12.0+cu113)
# Requirement already satisfied: beautifulsoup4 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (4.9.3)
# Requirement already satisfied: nvidia-ml-py3 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (7.352.0)
# Requirement already satisfied: bottleneck in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.3.2)
# Requirement already satisfied: pandas in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.1.5)
# Requirement already satisfied: numpy>=1.15 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.19.0)
# Requirement already satisfied: scipy in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.6.2)
# Requirement already satisfied: matplotlib in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.4.2)
# Requirement already satisfied: numexpr in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.7.1)
# Requirement already satisfied: pyyaml in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (5.3.1)
# Requirement already satisfied: torch>=1.0.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.11.0+cu113)
# Requirement already satisfied: spacy>=2.0.18 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.5.0)
# Requirement already satisfied: fastprogress>=0.2.1 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.0.3)
# Requirement already satisfied: packaging in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (20.9)
# Requirement already satisfied: requests in /home/tsmc/anaconda3/lib/python3.8/site-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.25.1)
# Requirement already satisfied: scikit-image>=0.11.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from imgaug==0.2.6->-r requirements-colab.txt (line 8)) (0.17.2)
# Requirement already satisfied: six in /home/tsmc/anaconda3/lib/python3.8/site-packages (from imgaug==0.2.6->-r requirements-colab.txt (line 8)) (1.15.0)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from tensorboardX>=1.6->-r requirements-colab.txt (line 2)) (3.20.3)
# Requirement already satisfied: networkx>=2.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from scikit-image>=0.11.0->imgaug==0.2.6->-r requirements-colab.txt (line 8)) (2.5)
# Requirement already satisfied: imageio>=2.3.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from scikit-image>=0.11.0->imgaug==0.2.6->-r requirements-colab.txt (line 8)) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from scikit-image>=0.11.0->imgaug==0.2.6->-r requirements-colab.txt (line 8)) (2020.12.8)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from scikit-image>=0.11.0->imgaug==0.2.6->-r requirements-colab.txt (line 8)) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from matplotlib->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.8.1)
# Requirement already satisfied: decorator>=4.3.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from networkx>=2.0->scikit-image>=0.11.0->imgaug==0.2.6->-r requirements-colab.txt (line 8)) (4.4.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (4.59.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.4.5)
# Requirement already satisfied: jinja2 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.11.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.1.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (8.1.7)
# Requirement already satisfied: setuptools in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (59.5.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.10.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.0.8)
# Requirement already satisfied: pathy>=0.10.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.10.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from requests->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from requests->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from requests->fastai==1.0.60->-r requirements-colab.txt (line 1)) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from requests->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2021.5.30)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from typer<0.8.0,>=0.3.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (7.1.2)
# Requirement already satisfied: future in /home/tsmc/anaconda3/lib/python3.8/site-packages (from ffmpeg-python->-r requirements-colab.txt (line 3)) (0.18.2)
# Requirement already satisfied: pycryptodomex in /home/tsmc/anaconda3/lib/python3.8/site-packages (from yt-dlp->-r requirements-colab.txt (line 4)) (3.17)
# Requirement already satisfied: websockets in /home/tsmc/anaconda3/lib/python3.8/site-packages (from yt-dlp->-r requirements-colab.txt (line 4)) (9.1)
# Requirement already satisfied: mutagen in /home/tsmc/anaconda3/lib/python3.8/site-packages (from yt-dlp->-r requirements-colab.txt (line 4)) (1.46.0)
# Requirement already satisfied: brotli in /home/tsmc/anaconda3/lib/python3.8/site-packages (from yt-dlp->-r requirements-colab.txt (line 4)) (1.0.9)
# Requirement already satisfied: soupsieve>1.2 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from jinja2->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.1.1)
# Requirement already satisfied: pytz>=2017.2 in /home/tsmc/anaconda3/lib/python3.8/site-packages (from pandas->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2020.5)
# WARNING: Keyring is skipped due to an exception: Failed to unlock the collection!

# %%
import fastai
from deoldify.visualize import *

torch.backends.cudnn.benchmark = True

# %%
# !mkdir 'models'
# !wget https://www.dropbox.com/s/axsd2g85uyixaho/ColorizeStable_gen.pth?dl=0 -O ./models/ColorizeStable_gen.pth
# Out:
# mkdir: cannot create directory ‘models’: File exists
# --2023-03-15 10:27:57--  https://www.dropbox.com/s/axsd2g85uyixaho/ColorizeStable_gen.pth?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.85.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.85.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw
dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 874066230 (834M) [application/octet-stream]
# Saving to: ‘./models/ColorizeStable_gen.pth’
#
# ./models/ColorizeSt 100%[===================>] 833.57M  9.04MB/s    in 97s
#
# 2023-03-15 10:29:36 (8.58 MB/s) - ‘./models/ColorizeStable_gen.pth’ saved [874066230/874066230]

# %%
colorizer = get_image_colorizer(artistic=False)
# Out:
# /media/tsmc/E/hgsh/DeOldify/fastai/data_block.py:451: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /media/tsmc/E/hgsh/DeOldify/fastai/data_block.py:453: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   warn("""Your validation set is empty. If this is by design, use `split_none()`

# %% [markdown]
# #◢ Instructions

# %% [markdown]
# ### source_url
# Type in a url to a direct link of an image.  Usually that means they'll end in .png, .jpg, etc. NOTE: If you want to use your own image, upload it first to a site like Imgur.
#
# ### render_factor
# The default value of 35 has been carefully chosen and should work -ok- for most scenarios (but probably won't be the -best-). This determines resolution at which the color portion of the image is rendered. Lower resolution will render faster, and colors also tend to look more vibrant. Older and lower quality images in particular will generally benefit by lowering the render factor. Higher render factors are often better for higher quality images, but the colors may get slightly washed out.
#
# ### watermarked
# Selected by default, this places a watermark icon of a palette at the bottom left corner of the image.  This is intended to be a standard way to convey to others viewing the image that it is colorized by AI. We want to help promote this as a standard, especially as the technology continues to improve and the distinction between real and fake becomes harder to discern. This palette watermark practice was initiated and lead by the company MyHeritage in the MyHeritage In Color feature (which uses a newer version of DeOldify than what you're using here).
#
# #### How to Download a Copy
# Simply right click on the displayed image and click "Save image as..."!
#
# ## Pro Tips
#
# You can evaluate how well the image is rendered at each render_factor by using the code at the bottom (that cell under "See how well render_factor values perform on a frame here").

# %% [markdown]
# #◢ Colorize!!

# %%
source_url = '' #@param {type:"string"}
render_factor = 35  #@param {type: "slider", min: 7, max: 40}
watermarked = True #@param {type:"boolean"}

if source_url is not None and source_url !='':
    image_path = colorizer.plot_transformed_image_from_url(url=source_url, render_factor=render_factor, compare=True, watermarked=watermarked)
    show_image_in_notebook(image_path)
else:
    print('Provide an image url and try again.')
# Out:
# Provide an image url and try again.

# %% [markdown]
# ## See how well render_factor values perform on the image here

# %%
#for i in range(10,40,2):
colorizer.plot_transformed_image('/media/tsmc/E/hgsh/DeOldify(scale:gray=8:2)/input/8-NB.png', render_factor=32, display_render_factor=True, figsize=(8,8))
# Out:
# PosixPath('result_images/8-NB.png')

# %% [markdown]
# ---
# #⚙ Recommended image sources
# * [/r/TheWayWeWere](https://www.reddit.com/r/TheWayWeWere/)
